# %%
import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
pd.set_option('display.max_columns', None)   # показывать все колонки
pd.set_option('display.width', 200)          # увеличить ширину строки
pd.set_option('display.max_colwidth', None)  # показать полный контент ячеек

df = pd.read_csv('HW1_var_16.csv', sep=';')
df_desc = pd.read_csv('!Описание параметров_Description of parameters_sas_2022_hw1.csv', encoding='cp1251', sep=';')
df_desc
# Out:
#                  Атрибуты                                                                                                                                            Описание  \
# 0          Номер варианта                                                                                                                                      Номер варианта
# 1                      ID                                                                                                                               Идентификатор клиента
# 2        INCOME_BASE_TYPE                                                                                                                                Подтверждение дохода
# 3          CREDIT_PURPOSE                                                                                                                              Цель получения кредита
# 4          INSURANCE_FLAG                                                                                                          Страхование заемщика при получении кредита
# 5                     DTI                                                                                                    debt-to-income ratio — отношение долга к доходам
# 6                     SEX                                                                                                                                                 Пол
# 7   FULL_AGE_CHILD_NUMBER                                                                                                                                  Кол-во лет ребенку
# 8        DEPENDANT_NUMBER                                                                                                                                   Кол-во иждивенцев
# 9               EDUCATION                                                                                                                                         Образование
# 10              EMPL_TYPE                                                                                                                                           Должность
# 11              EMPL_SIZE                                                                                                                                            Зарплата
# 12       BANKACCOUNT_FLAG  Кол-во аккаунтов у клиента. ( 0 - нет онлайн -кабинета , 1 - есть один онлайн-кабинет, 2 и более - заходил в онлайн кабинет с другого устройства )
# 13         Period_at_work                                                                                                                          Время работы (кол-во дней)
# 14                    age                                                                                                                                             Возраст
# 15          EMPL_PROPERTY                                                                                                                          Сфера бизнеса работодателя
# 16              EMPL_FORM                                                                                                                     Организационно - правовая форма
# 17          FAMILY_STATUS                                                                                                                                     Семейный статус
# 18              max90days                                                                                       кол-во запросов в бюро кредитных историй за последние 90 дней
# 19              max60days                                                                                       кол-во запросов в бюро кредитных историй за последние 60 дней
# 20              max30days                                                                                       кол-во запросов в бюро кредитных историй за последние 30 дней
# 21              max21days                                                                                       кол-во запросов в бюро кредитных историй за последние 21 дней
# 22              max14days                                                                                       кол-во запросов в бюро кредитных историй за последние 14 дней
# 23          avg_num_delay                                                                                                                      Среднее кол-во задержки оплаты
# 24               if_zalog                                                                                                                    Наличие залога (квартира,машина)
# 25   num_AccountActive180                                                                                                 кол-во активных счетов счетов за последние 180 дней
# 26    num_AccountActive90                                                                                                  кол-во активных счетов счетов за последние 90 дней
# 27    num_AccountActive60                                                                                                  кол-во активных счетов счетов за последние 60 дней
# 28      Active_to_All_prc                                                                                                            отношение активных счетов ко всем счетам
# 29    numAccountActiveAll                                                                                                                              кол-во открытых счетоа
# 30       numAccountClosed                                                                                                                              кол-во закрытых счетов
# 31     sum_of_paym_months                                                                                                            сумма платежей за последний месяц (тыс.)
# 32            all_credits                                                                                                                                     Кол-во кредитов
# 33          Active_not_cc                                                                                                     Активные кредитные счета, но не кредитная карта
# 34             own_closed                                                                                                                            Кол-во закрытых кредитов
# 35      min_MnthAfterLoan                      минимальное кол-во месяцев, которое прошло с момета взятия прошлого кредита, то есть как давно выдали последний кредит клиенту
# 36      max_MnthAfterLoan                                                                                           кол-во месяцев прошеднее с момента выдачи первого кредита
# 37              dlq_exist                                                                                                                  наличие просрочки на данный момент
# 38       thirty_in_a_year                                                                                                           просрочка больше 30 дней за последний год
# 39        sixty_in_a_year                                                                                                           просрочка больше 60 дней за последний год
# 40       ninety_in_a_year                                                                                                           просрочка больше 90 дней за последний год
# 41         thirty_vintage                                                                                                               просрочка больше 30 дней, когда-либо
# 42          sixty_vintage                                                                                                               просрочка больше 60 дней, когда-либо
# 43         ninety_vintage                                                                                                               просрочка больше 90 дней, когда-либо
#
#                                                                                                                                                      Description
# 0                                                                                                                                                 Variant number
# 1                                                                                                                                                      Client ID
# 2                                                                                                                                            Income verification
# 3                                                                                                                                            Purpose of the loan
# 4                                                                                                                     Borrower's insurance when receiving a loan
# 5                                                                                                             debt-to-income ratio - the ratio of debt to income
# 6                                                                                                                                                          Floor
# 7                                                                                                                                   Number of years of the child
# 8                                                                                                                                           Number of dependents
# 9                                                                                                                                                      Education
# 10                                                                                                                                                      Position
# 11                                                                                                                                                        Salary
# 12  The number of accounts the client has. (0 - no online account, 1 - there is one online account, 2 or more - accessed the online account from another device)
# 13                                                                                                                                 Working time (number of days)
# 14                                                                                                                                                           Age
# 15                                                                                                                                        Employer business area
# 16                                                                                                                                 Organizational and legal form
# 17                                                                                                                                                 Family status
# 18                                                                                                      number of requests to credit bureaus in the last 90 days
# 19                                                                                                      number of requests to credit bureaus in the last 60 days
# 20                                                                                                      number of requests to credit bureaus in the last 30 days
# 21                                                                                                      number of requests to credit bureaus in the last 21 days
# 22                                                                                                      number of requests to credit bureaus in the last 14 days
# 23                                                                                                                              Average number of payment delays
# 24                                                                                                                       Presence of collateral (apartment, car)
# 25                                                                                                      number of active accounts accounts for the last 180 days
# 26                                                                                                        number of active accounts accounts in the last 90 days
# 27                                                                                                        number of active accounts accounts in the last 60 days
# 28                                                                                                                      ratio of active accounts to all accounts
# 29                                                                                                                                       number of open accounts
# 30                                                                                                                                     number of closed accounts
# 31                                                                                                              amount of payments for the last month (thousand)
# 32                                                                                                                                             Number of credits
# 33                                                                                                                     Active credit accounts but no credit card
# 34                                                                                                                                        Number of closed loans
# 35                     the minimum number of months that have passed since the last loan was taken, that is, how long ago the last loan was issued to the client
# 36                                                                                                        number of months past since the date of the first loan
# 37                                                                                                                                          currently in arrears
# 38                                                                                                                    overdue more than 30 days in the last year
# 39                                                                                                                    overdue more than 60 days in the last year
# 40                                                                                                                    overdue more than 90 days in the last year
# 41                                                                                                                               overdue more than 30 days, ever
# 42                                                                                                                               overdue more than 60 days, ever
# 43                                                                                                                               overdue more than 90 days, ever
