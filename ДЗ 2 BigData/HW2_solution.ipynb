# %%
import re
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import spacy

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# !python -m spacy download ru_core_news_sm
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/v.makshanchikov/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/v.makshanchikov/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/v.makshanchikov/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Collecting ru-core-news-sm==3.8.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.8.0/ru_core_news_sm-3.8.0-py3-none-any.whl (15.3 MB)
# Requirement already satisfied: pymorphy3>=1.0.0 in /opt/anaconda3/envs/hwenv/lib/python3.13/site-packages (from ru-core-news-sm==3.8.0) (2.0.6)
# Requirement already satisfied: dawg2-python>=0.8.0 in /opt/anaconda3/envs/hwenv/lib/python3.13/site-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.8.0) (0.9.0)
# Requirement already satisfied: pymorphy3-dicts-ru in /opt/anaconda3/envs/hwenv/lib/python3.13/site-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.8.0) (2.4.417150.4580142)
# Requirement already satisfied: setuptools>=68.2.2 in /opt/anaconda3/envs/hwenv/lib/python3.13/site-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.8.0) (80.9.0)
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')

# %%
files = ["soltwine1.txt", "soltwine2.txt", "soltwine3.txt"]

texts = []
for file in files:
    with open(file, "r", encoding="utf-8") as f:
        texts.append(f.read())

texts
# Out:
# ['Мне не хочется знать о том, как у тебя дела\nНо ты выглядишь так привлекательно\nДля тебя всё сегодня бесплатно\nЕдь ко мне сразу без платья\nМог бы соврать, но я не столько хочу тебя\nСколько просто ищу тепла\nЯ бы мог написать другой\nТы просто была под рукой\nПриезжай уже, ты такая же\nНам обоим плевать, что у нас в душе\nТы сама намекала на это же\nПозвони мне, как будешь на этаже\nЕсли будет паршиво, мы снова друг другу напишем и поможем\nПереспим, а потом я скажу, как тоскую по бывшей, ты же тоже?\nНам покажется, будто сейчас мы становимся ближе, не похоже\nПереспим, а потом я скажу, как тоскую по бывшей, ты же тоже? Ты же тоже?\nЕсли ты едешь ко мне не ищи во мне принца\nНа белом коне или рыцаря\nВ планах на вечер напиться\nЧтоб усыпить свои взгляды и принципы\nТак веселей будет падать ко дну\nВедь ничего не стоит на кону\nИ мы ничего не должны никому\nНо откуда я чувствую стыд и вину?\nБезобидная шалость:\nПо бокалу — и можем раздеться\nНо в груди заболело и сжалось\nЧто-то в области сердца\nЧто это: страсть или жалость?\nВот это загадка\nПочему мне становится гадко?\nНедочёт идеального плана\nЗначит, я недостаточно пьяный\nПойдём за добавкой\nЕсли будет паршиво, мы снова друг другу напишем и поможем\nПереспим, а потом я скажу, как тоскую по бывшей, ты же тоже?\nНам покажется, будто сейчас мы становимся ближе — не похоже\nПереспим, а потом я скажу, как тоскую по бывшей, ты же тоже? Ты же тоже?',
#  'Ну какая молодец ты\nУ твоих бывших был отличный вкус\nШкола с красным аттестатом и столичный вуз\nДаже не удивлюсь, если ты готовилась с детства\nНе думал я, что так легко влюблюсь\nПроходишь на бюджет и ходишь послушно на пары\nА я сто лет уже пою за копейки по барам местным\nИ так уверен, что стану известным\nЯ постоянно пью и пишу эти песни\nМы должны были не встретиться никогда\nУ нас разные уклады и города\nКак сильно можно изменить всё за пару дней\nЯ уже спрашивал, ну что ты нашла во мне?\nПокажи мне Москву\nПогнали на улицу, какая ты умница\nЯ начал это, я эту стену прорву\nМне так это нравится\nИ я хочу довести до конца наше с тобой рандеву\nПогнали на улицу, какая ты умница\nЯ начал это, я эту стену прорву\nМне так это нравится\nИ я хочу довести до конца наше с тобой рандеву\nПрежде, чем провести тебя домой\nЯ повёл тебя, как подросток, по центральной набережной\nПредельно честно говорю тебе, может и не поверишь, но\nЯ впервые вёл себя с кем-то тихо и бережно\nТак, декорации сменяются на городской парк\nНаши тела спускаются в любимый мой бар\nРезкая смена кадров, у меня едет чердак\nНо я запомнил этот день в самых подробных чертах\nВ голове не осталось здоровых мыслей\nВезде и всюду только: «мы с ней, мы с ней, мы с ней»\nПопали в эту яму, ну что же теперь?\nТеперь мы пьяные поехали прямо к тебе\nВходная дверь закрывается на засов\nНас не волнует то, что мы с тобой знакомы лишь пару часов\nИ весь сюжет ускоряется в обороте\nИ вот ты сидишь напротив, и вроде бы ты не против была\nПадают без памяти наши тела\nНо я в подробностях запомнил, как ты выглядела\nПора сказать друг другу честно, как наши дела\nЯ снимаю маску\nПокажи мне Москву\nПогнали на улицу, какая ты умница\nЯ начал это, я эту стену прорву\nМне так это нравится\nИ я хочу довести до конца наше с тобой рандеву\nПогнали на улицу, какая ты умница\nЯ начал это, я эту стену прорву\nМне так это нравится\nИ я хочу довести до конца, довести до конца, довести до конца\nНаше с тобой рандеву',
#  'Клубок из обид и тревог\nНачинается паника\nЯ бегу от тебя со всех ног\nСразу, как только увижу издалека\nНе смог, я хотел, но не смог\nИграть безмятежного паренька\nЯ ненавижу тебя, когда вижу тебя\nНачинается паника\nМы провалим любое пари\nМы самый поганый дуэт\nВыйти с тобой поговорить\nЗначит выйти с тобой на дуэль\nЯ на пределе\nТолько и делаем тут, что терпим и что-то делим\nСнова прощаем, опять огорчаемся\nСнова тупое молчанье, глухая печаль\nДаже если исчезнешь сейчас\nТы успела оставить печать на мне\nТы истощаешь\nМне тебя не забыть, но я точно не буду скучать\nКлубок из обид и тревог\nНачинается паника\nЯ бегу от тебя со всех ног\nСразу, как только увижу издалека\nНе смог, я хотел, но не смог\nИграть безмятежного паренька\nЯ ненавижу тебя, когда вижу тебя\nНачинается паника\nОстаётся одно\nЛибо проститься с тобой, либо выйти в окно\n"Ваше последнее слово?"\n"Желаю тебе всего самого злого"\nЗажмурь глаза, считай до ста\nПрыжок с подожжённого нами моста\nТы же тоже устала\nЯ знаю, хотелось как лучше\nНо лучше не стало, осталось лишь\nПостоянное избегание\nСоблюдение расстояния\nПросто я не я\nТы вошла во вкус\nРасставания\nЯ тебя боюсь\nКлубок из обид и тревог\nНачинается паника\nЯ бегу от тебя со всех ног\nСразу, как только увижу издалека\nНе смог, я хотел, но не смог\nИграть безмятежного паренька\nЯ ненавижу тебя, когда вижу тебя\nНачинается паника']

# %%
def preprocess(text):
    # Нижний регистр
    text = text.lower()
    
    # Удаление всего кроме букв
    text = re.sub(r"[^а-яё\s]", " ", text)
    
    # Обработка через spaCy
    doc = nlp(text)
    
    tokens = []
    for token in doc:
        # Убираем стоп-слова, пунктуацию, пробелы и короткие слова
        if (
            not token.is_stop
            and not token.is_punct
            and not token.is_space
            and len(token.lemma_) > 2
        ):
            tokens.append(token.lemma_)
    
    return " ".join(tokens)

# %%
for i, text in enumerate(texts):
    print(f"Песня {i+1}: {len(text.split())} слов до очистки")

nlp = spacy.load("ru_core_news_sm")
cleaned_texts = [preprocess(text) for text in texts]

# Проверка размера текстов
for i, text in enumerate(cleaned_texts):
    print(f"Песня {i+1}: {len(text.split())} слов после очистки")

cleaned_texts
# Out:
# Песня 1: 258 слов до очистки
# Песня 2: 366 слов до очистки
# Песня 3: 231 слов до очистки
# Песня 1: 97 слов после очистки
# Песня 2: 157 слов после очистки
# Песня 3: 107 слов после очистки
# ['хотеться знать дело выглядеть привлекательно сегодня бесплатно едь платье соврать столько искать тепло написать рука приезжай оба плевать душа намекать позвонить этаж паршиво друг другу написать поможем переспать сказать тоскую бывший показаться становиться близкий похожий переспать сказать тоскую бывший ехать искать принц белый конь рыцарь план вечер напиться усыпить взгляд принцип веселей падать дно стоить кон чувствовать стыд вина безобидный шалость бокал раздеться грудь заболеть сжалось область сердце страсть жалость загадка становиться гадко недочёт идеальный план недостаточно пьяный пойти добавка паршиво друг другу написать поможем переспать сказать тоскую бывший показаться становиться близкий похожий переспать сказать тоскую бывший',
#  'молодец бывший отличный вкус школа красный аттестат столичный вуз удивиться готовиться детство думать легко влюблюсь проходить бюджет ходить послушно пара сто год поить копейка барин местный уверенный стать известный постоянно пить писать песня встретиться разный уклад город сильно изменить пара день спрашивать найти покажи москва погнать улица умница начать стена прорвать нравиться довести конец рандеву погнать улица умница начать стена прорвать нравиться довести конец рандеву провести домой повёл подросток центральный набережная предельно честно говорить поверить впервые вёл тихо бережный декорация сменяться городской парк тело спускаться любимый бар резкий смена кадр ехать чердак запомнить день подробный чертах голова остаться здоровый мысль попасть яма пьяный поехать прямо входной дверь закрываться засов волновать знакомый пара час сюжет ускоряться оборот сидеть против падать память тело подробность запомнить выглядеть сказать друг другу честно дело снимать маска покажи москва погнать улица умница начать стена прорвать нравиться довести конец рандеву погнать улица умница начать стена прорвать нравиться довести конец довести конец довести конец рандеву',
#  'клубок обида тревог начинаться паника бежать нога увидеть издалёка смочь смочь играть безмятежный паренёк ненавидеть видеть начинаться паника провалить пари поганый дуэт выйти поговорить выйти дуэль предел делать терпеть делим прощать огорчаться тупой молчание глухой печаль исчезнешь успеть оставить печать истощать забыть скучать клубок обида тревог начинаться паника бежать нога увидеть издалёка смочь смочь играть безмятежный паренёк ненавидеть видеть начинаться паника оставаться проститься выйти окно последний слово желать злой зажмурь глаз считай сто прыжок подожжённого мост устать знать хороший лучше остаться постоянный избегание соблюдение расстояние войти вкус расставание бояться клубок обида тревог начинаться паника бежать нога увидеть издалёка смочь смочь играть безмятежный паренёк ненавидеть видеть начинаться паника']

# %% [markdown]
# - Объём текстов сократился примерно на 55–65%.
# - Это означает, что:
# - стоп-слова удалены корректно,
# - лемматизация работает,
# - шум (частицы, союзы, повторы) устранён.

# %%
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# Объединяем тексты в один корпус
all_tokens = " ".join(cleaned_texts).split()

word_counts = Counter(all_tokens)

# Топ-15 слов
top_words = word_counts.most_common(15)

df_top = pd.DataFrame(top_words, columns=["Слово", "Частота"])

plt.figure()
sns.barplot(data=df_top, x="Частота", y="Слово")
plt.title("Топ-15 наиболее частых слов (после очистки)")
plt.show()
